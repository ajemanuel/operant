# %%
import numpy as np
import matplotlib.pyplot as plt
import compress_pickle as pickle
# %matplotlib inline

# %%
    temp = pickle.load(r'E:/DATA/Behavior/20210723')

# %%
plt.figure(figsize=[5,20])
for trial in temp['di_data'].keys():
    if temp['results'][trial] == 'hit':
        plt.plot(temp['di_data'][trial]+trial,color='b')
    elif temp['results'][trial] == 'FA':
        plt.plot(temp['di_data'][trial]+trial,color='r')
    else:
        plt.plot(temp['di_data'][trial]+trial,color='gray')
        
plt.xlabel('Samples')
plt.ylabel('Trial')
# Out:
# Text(0, 0.5, 'Trial')

# %%
results = temp['results']

# %%
for startTrial in np.arange(0,results.shape[0]-200,5):
# Out:
#   File "<ipython-input-6-9d3c376b7ef2>", line 2
#
#     ^
# SyntaxError: unexpected EOF while parsing
